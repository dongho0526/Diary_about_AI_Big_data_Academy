# %%
import pandas as pd

# %%
df = pd.read_csv('Car.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Price              6200 non-null   float64
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %%
df.head()
# Out:
#                                Name    Location     Price  Year  \
# 0            Maruti Wagon R LXI CNG      Mumbai   2682.68  2010
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                      Honda Jazz V     Chennai   6898.32  2011
# 3                 Maruti Ertiga VDI     Chennai   9197.76  2012
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First   26.6 kmpl   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price
# 0  58.16 bhp    5.0        NaN
# 1  126.2 bhp    5.0        NaN
# 2   88.7 bhp    5.0  8.61 Lakh
# 3  88.76 bhp    7.0        NaN
# 4  140.8 bhp    5.0        NaN

# %%
df['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                  Maruti Wagon R LXI CNG
# 1                        Hyundai Creta 1.6 CRDi SX Option
# 2                                            Honda Jazz V
# 3                                       Maruti Ertiga VDI
# 4                         Audi A4 New 2.0 TDI Multitronic
#                               ...
# 7248                    Volkswagen Vento Diesel Trendline
# 7249                               Volkswagen Polo GT TSI
# 7250                               Nissan Micra Diesel XV
# 7251                               Volkswagen Polo GT TSI
# 7252    Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...
# Name: Name, Length: 7253, dtype: object>

# %%
df.isna().sum()
# Out:
# Name                    0
# Location                0
# Price                1053
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# dtype: int64

# %%
df['Name'] = df['Name'].apply(lambda x: 'Land-Rover' if 'Land Rover' in x else x)
df['Brand'] = df['Name'][:].str.split(' ').str[0]

split_names = df['Name'].str.split(' ')
joined_brands = split_names.apply(lambda x: ' '.join(x[1:]))
df['Name'] = joined_brands

# 단위 떼기
# df[['Power', 'Power_UNIT']] = df['Power'].str.split(expand = True)

# %%
df
# Out:
#                                         Name    Location     Price  Year  \
# 0                            Wagon R LXI CNG      Mumbai   2682.68  2010
# 1                   Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                                     Jazz V     Chennai   6898.32  2011
# 3                                 Ertiga VDI     Chennai   9197.76  2012
# 4                 A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
# ...                                      ...         ...       ...   ...
# 7248                  Vento Diesel Trendline   Hyderabad       NaN  2011
# 7249                             Polo GT TSI      Mumbai       NaN  2015
# 7250                         Micra Diesel XV     Kolkata       NaN  2012
# 7251                             Polo GT TSI        Pune       NaN  2013
# 7252  E-Class 2009-2013 E 220 CDI Avantgarde       Kochi       NaN  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First   26.6 kmpl
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price          Brand
# 0      998 CC  58.16 bhp    5.0        NaN         Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN        Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh          Honda
# 3     1248 CC  88.76 bhp    7.0        NaN         Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN           Audi
# ...       ...        ...    ...        ...            ...
# 7248  1598 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7249  1197 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7250  1461 CC   63.1 bhp    5.0        NaN         Nissan
# 7251  1197 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7252  2148 CC    170 bhp    5.0        NaN  Mercedes-Benz
#
# [7253 rows x 14 columns]

# %%
df['Brand'].value_counts()
# Out:
# Maruti           1444
# Hyundai          1340
# Honda             743
# Toyota            507
# Mercedes-Benz     380
# Volkswagen        374
# Ford              351
# Mahindra          331
# BMW               312
# Audi              285
# Tata              228
# Skoda             202
# Renault           170
# Chevrolet         151
# Nissan            117
# Land-Rover         67
# Jaguar             48
# Fiat               38
# Mitsubishi         36
# Mini               31
# Volvo              28
# Porsche            19
# Jeep               19
# Datsun             17
# ISUZU               5
# Force               3
# Bentley             2
# Smart               1
# Ambassador          1
# Lamborghini         1
# Hindustan           1
# OpelCorsa           1
# Name: Brand, dtype: int64

# %%
df
# Out:
#                                         Name    Location     Price  Year  \
# 0                            Wagon R LXI CNG      Mumbai   2682.68  2010
# 1                   Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                                     Jazz V     Chennai   6898.32  2011
# 3                                 Ertiga VDI     Chennai   9197.76  2012
# 4                 A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
# ...                                      ...         ...       ...   ...
# 7248                  Vento Diesel Trendline   Hyderabad       NaN  2011
# 7249                             Polo GT TSI      Mumbai       NaN  2015
# 7250                         Micra Diesel XV     Kolkata       NaN  2012
# 7251                             Polo GT TSI        Pune       NaN  2013
# 7252  E-Class 2009-2013 E 220 CDI Avantgarde       Kochi       NaN  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First   26.6 kmpl
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price          Brand
# 0      998 CC  58.16 bhp    5.0        NaN         Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN        Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh          Honda
# 3     1248 CC  88.76 bhp    7.0        NaN         Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN           Audi
# ...       ...        ...    ...        ...            ...
# 7248  1598 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7249  1197 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7250  1461 CC   63.1 bhp    5.0        NaN         Nissan
# 7251  1197 CC  103.6 bhp    5.0        NaN     Volkswagen
# 7252  2148 CC    170 bhp    5.0        NaN  Mercedes-Benz
#
# [7253 rows x 14 columns]

# %%
brands = {
    'India': ['Maruti', 'Tata', 'Land-Rover', 'Mahindra', 'Ambassador', 'Force', 'Hindustan'],
    'Japan': ['Honda', 'Toyota', 'Mitsubishi', 'ISUZU', 'Nissan', 'Datsun'],
    'Korea': ['Hyundai'],
    'Germany': ['Volkswagen', 'Mercedes-Benz', 'BMW', 'Porsche', 'Audi', 'Skoda', 'Mini', 'Smart', 'OpelCorsa'],
    'France': ['Renault'],
    'USA': ['Ford', 'Chevrolet', 'Jeep'],
    'UK': ['Jaguar', 'Bentley'],
    'Sweden': ['Volvo'],
    'Italy': ['Fiat', 'Lamborghini']
}

# %%
brand_country = {brand: country for country, brands_list in brands.items() for brand in brands_list}

df['Country'] = df['Brand'].map(brand_country)

# %%
df.head()
# Out:
#                          Name    Location     Price  Year  Kilometers_Driven  \
# 0             Wagon R LXI CNG      Mumbai   2682.68  2010              72000
# 1    Creta 1.6 CRDi SX Option        Pune  19162.00  2015              41000
# 2                      Jazz V     Chennai   6898.32  2011              46000
# 3                  Ertiga VDI     Chennai   9197.76  2012              87000
# 4  A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price    Brand  Country
# 0        NaN   Maruti    India
# 1        NaN  Hyundai    Korea
# 2  8.61 Lakh    Honda    Japan
# 3        NaN   Maruti    India
# 4        NaN     Audi  Germany

# %%
df['Country'].isnull().value_counts()
# Out:
# False    7253
# Name: Country, dtype: int64

# %%
null_rows = df[df['Country'].isnull()]
print(null_rows)
# Out:
# Empty DataFrame
# Columns: [Name, Location, Price, Year, Kilometers_Driven, Fuel_Type, Transmission, Owner_Type, Mileage, Engine, Power, Seats, New_Price, Brand, Country]
# Index: []

# %%
continents = {
    'Europe' : ['Germany', 'France', 'Sweden', 'Italy', 'UK'],
    'Asia' : ['Korea', 'Japan', 'India'],
    'America' : ['USA']
}


# brand_country = {brand: country for country, brands_list in brands.items() for brand in brands_list}

# df['Country'] = df['Brand'].map(brand_country)

# %%
brand_continent = {}
for continent, countries in continents.items():
    for country in countries:
        brand_continent[country] = continent

# 대륙 정보 기반으로 새로운 열 추가
df['Continent'] = df['Country'].map(brand_continent)

# 결과 확인
df
# Out:
#                                         Name    Location     Price  Year  \
# 0                            Wagon R LXI CNG      Mumbai   2682.68  2010
# 1                   Creta 1.6 CRDi SX Option        Pune  19162.00  2015
# 2                                     Jazz V     Chennai   6898.32  2011
# 3                                 Ertiga VDI     Chennai   9197.76  2012
# 4                 A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013
# ...                                      ...         ...       ...   ...
# 7248                  Vento Diesel Trendline   Hyderabad       NaN  2011
# 7249                             Polo GT TSI      Mumbai       NaN  2015
# 7250                         Micra Diesel XV     Kolkata       NaN  2012
# 7251                             Polo GT TSI        Pune       NaN  2013
# 7252  E-Class 2009-2013 E 220 CDI Avantgarde       Kochi       NaN  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First   26.6 kmpl
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price          Brand  Country Continent
# 0      998 CC  58.16 bhp    5.0        NaN         Maruti    India      Asia
# 1     1582 CC  126.2 bhp    5.0        NaN        Hyundai    Korea      Asia
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh          Honda    Japan      Asia
# 3     1248 CC  88.76 bhp    7.0        NaN         Maruti    India      Asia
# 4     1968 CC  140.8 bhp    5.0        NaN           Audi  Germany    Europe
# ...       ...        ...    ...        ...            ...      ...       ...
# 7248  1598 CC  103.6 bhp    5.0        NaN     Volkswagen  Germany    Europe
# 7249  1197 CC  103.6 bhp    5.0        NaN     Volkswagen  Germany    Europe
# 7250  1461 CC   63.1 bhp    5.0        NaN         Nissan    Japan      Asia
# 7251  1197 CC  103.6 bhp    5.0        NaN     Volkswagen  Germany    Europe
# 7252  2148 CC    170 bhp    5.0        NaN  Mercedes-Benz  Germany    Europe
#
# [7253 rows x 16 columns]

# %%
df['Continent'] = df['Country'].map(brand_continent)

# %%
df.head()
# Out:
#                          Name    Location     Price  Year  Kilometers_Driven  \
# 0             Wagon R LXI CNG      Mumbai   2682.68  2010              72000
# 1    Creta 1.6 CRDi SX Option        Pune  19162.00  2015              41000
# 2                      Jazz V     Chennai   6898.32  2011              46000
# 3                  Ertiga VDI     Chennai   9197.76  2012              87000
# 4  A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price    Brand  Country Continent
# 0        NaN   Maruti    India      Asia
# 1        NaN  Hyundai    Korea      Asia
# 2  8.61 Lakh    Honda    Japan      Asia
# 3        NaN   Maruti    India      Asia
# 4        NaN     Audi  Germany    Europe

# %%
df['Continent'].isnull().value_counts()
# Out:
# False    7253
# Name: Continent, dtype: int64

# %% [markdown]
# 도시 확인

# %%
df['Location'].value_counts()
# Out:
# Mumbai        949
# Hyderabad     876
# Coimbatore    772
# Kochi         772
# Pune          765
# Delhi         660
# Kolkata       654
# Chennai       591
# Jaipur        499
# Bangalore     440
# Ahmedabad     275
# Name: Location, dtype: int64

# %%
df.head()
# Out:
#                          Name    Location     Price  Year  Kilometers_Driven  \
# 0             Wagon R LXI CNG      Mumbai   2682.68  2010              72000
# 1    Creta 1.6 CRDi SX Option        Pune  19162.00  2015              41000
# 2                      Jazz V     Chennai   6898.32  2011              46000
# 3                  Ertiga VDI     Chennai   9197.76  2012              87000
# 4  A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price    Brand  Country Continent
# 0        NaN   Maruti    India      Asia
# 1        NaN  Hyundai    Korea      Asia
# 2  8.61 Lakh    Honda    Japan      Asia
# 3        NaN   Maruti    India      Asia
# 4        NaN     Audi  Germany    Europe

# %%
city_population = {
    'Mumbai' : 20961,
    'Hyderabad' : 10534,
    'Coimbatore' : 2935,
    'Kochi' : 3301,
    'Pune' : 6987,
    'Delhi' : 32066,
    'Kolkata' : 15134,
    'Chennai' : 11503,
    'Jaipur' : 4107,
    'Bangalore' :13193,
    'Ahmedabad' : 8450
} # 2022년 기준 인도 도시 별 인구수

# %%
df['City_population'] = df['Location'].map(city_population)

# %%
df.head()
# Out:
#                          Name    Location     Price  Year  Kilometers_Driven  \
# 0             Wagon R LXI CNG      Mumbai   2682.68  2010              72000
# 1    Creta 1.6 CRDi SX Option        Pune  19162.00  2015              41000
# 2                      Jazz V     Chennai   6898.32  2011              46000
# 3                  Ertiga VDI     Chennai   9197.76  2012              87000
# 4  A4 New 2.0 TDI Multitronic  Coimbatore  27194.71  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First   26.6 kmpl   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price    Brand  Country Continent  City_population
# 0        NaN   Maruti    India      Asia            20961
# 1        NaN  Hyundai    Korea      Asia             6987
# 2  8.61 Lakh    Honda    Japan      Asia            11503
# 3        NaN   Maruti    India      Asia            11503
# 4        NaN     Audi  Germany    Europe             2935

# %%
missing_values = df['City_population'].isna().sum()

if missing_values == 0:
    print("새로운 파생변수에 결측치가 없습니다.")
else:
    print(f"새로운 파생변수에 {missing_values}개의 결측치가 있습니다.")
# Out:
# 새로운 파생변수에 결측치가 없습니다.

# %%
print(df['Year'].sort_values(ascending=False))
# Out:
# 6815    2019
# 3196    2019
# 6982    2019
# 5067    2019
# 6586    2019
#         ...
# 5716    1998
# 3138    1998
# 4709    1998
# 3749    1998
# 6216    1996
# Name: Year, Length: 7253, dtype: int64
